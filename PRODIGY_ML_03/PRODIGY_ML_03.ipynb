# %%
import numpy as np
import os
import pandas as pd
from skimage.transform import resize
from skimage.io import imread
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
datadir = 'train2/'
target_arr = []
flat_data_arr = []

for i in os.listdir(datadir):
    img_array = imread(os.path.join(datadir,i))
    img_resized = resize(img_array,(150,150,3))
    flat_data_arr.append(img_resized.flatten())
    if('cat' in i):
        target_arr.append(0)
    if('dog' in i):
        target_arr.append(1)
target = np.array(target_arr)
flat_data = np.array(flat_data_arr)

# %%
category = ["cat","dog"]
df = pd.DataFrame(flat_data)
df['target'] = target
df['target_names'] = df["target"].apply(lambda x : category[x])
df[245:255]
# Out:
#             0         1         2         3         4         5         6  \
# 245  0.016830  0.048201  0.059966  0.014975  0.043849  0.056456  0.009241
# 246  0.401893  0.282841  0.079379  0.417979  0.301065  0.087075  0.446458
# 247  0.408287  0.390497  0.395992  0.375504  0.361682  0.374935  0.360810
# 248  0.710674  0.533716  0.373470  0.806725  0.619428  0.473539  0.835995
# 249  0.698039  0.698039  0.698039  0.698039  0.698039  0.698039  0.698039
#
#             7         8         9  ...     67492     67493     67494  \
# 245  0.023795  0.041760  0.005481  ...  0.150016  0.169624  0.137837
# 246  0.332638  0.098521  0.452123  ...  0.385377  0.279495  0.467726
# 247  0.354299  0.373890  0.381434  ...  0.747605  0.739702  0.751249
# 248  0.635132  0.494371  0.820874  ...  0.569063  0.495512  0.712050
# 249  0.698039  0.698039  0.698039  ...  0.403922  0.074510  0.631373
#
#         67495     67496     67497     67498     67499  target  target_names
# 245  0.149601  0.169209  0.144487  0.156252  0.175860       1           dog
# 246  0.385373  0.279491  0.466813  0.384460  0.278578       1           dog
# 247  0.701474  0.701485  0.665379  0.617315  0.624131       1           dog
# 248  0.540027  0.486357  0.601546  0.433821  0.396754       1           dog
# 249  0.403922  0.074510  0.631373  0.403922  0.074510       1           dog
#
# [5 rows x 67502 columns]

# %%
x = df.drop(["target","target_names"],axis=1)
y = df.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
GCV = GridSearchCV(SVC(kernel="poly"),{
    'C':[10,20,50],
    'kernel':["poly","rbf"]
},return_train_score=False)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(kernel='poly'),
#              param_grid={'C': [10, 20, 50], 'kernel': ['poly', 'rbf']})

# %%
GCV.best_params_
# Out:
# {'C': 10, 'kernel': 'poly'}

# %%
GCV.best_score_
# Out:
# 0.5549999999999999

# %%
# let's train the model
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
svm.score(x_test,y_test)
# Out:
# 0.68
